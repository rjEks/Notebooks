# %%
import pandas as pd
import numpy as np

#Importando Arquivos
dc_listings = pd.read_csv("D:\\Users\\313432\\Documents\\AirBNB\\listings.csv")

#Linhas x Colunsa
print(dc_listings.shape)

#Obtendo primeiras linhas
dc_listings.head()
# Out:
# (3723, 92)
#         id                           listing_url       scrape_id last_scraped  \
# 0  7087327  https://www.airbnb.com/rooms/7087327  20151002231825   2015-10-03
# 1   975833   https://www.airbnb.com/rooms/975833  20151002231825   2015-10-03
# 2  8249488  https://www.airbnb.com/rooms/8249488  20151002231825   2015-10-03
# 3  8409022  https://www.airbnb.com/rooms/8409022  20151002231825   2015-10-03
# 4  8411173  https://www.airbnb.com/rooms/8411173  20151002231825   2015-10-03
#
#                                  name  \
# 0  Historic DC Condo-Walk to Capitol!
# 1     Spacious Capitol Hill Townhouse
# 2    Spacious/private room for single
# 3    A wonderful bedroom with library
# 4              Downtown Silver Spring
#
#                                              summary  \
# 0  Professional pictures coming soon! Welcome to ...
# 1                                                NaN
# 2  This is an ideal room for a single traveler th...
# 3  Prime location right on the Potomac River in W...
# 4  Hi travellers! I live in this peaceful spot, b...
#
#                                                space  \
# 0                                                NaN
# 1  Beautifully renovated Capitol Hill townhouse. ...
# 2                                                NaN
# 3                                                NaN
# 4  This is a 750 sq ft 1 bedroom 1 bathroom.  Whi...
#
#                                          description experiences_offered  \
# 0  Professional pictures coming soon! Welcome to ...                none
# 1  Beautifully renovated Capitol Hill townhouse. ...                none
# 2  This is an ideal room for a single traveler th...                none
# 3  Prime location right on the Potomac River in W...                none
# 4  Hi travellers! I live in this peaceful spot, b...                none
#
#                                neighborhood_overview        ...         \
# 0                                                NaN        ...
# 1                                                NaN        ...
# 2                                                NaN        ...
# 3                                                NaN        ...
# 4  Silver Spring is booming.  You can walk to a n...        ...
#
#   review_scores_value requires_license license  \
# 0                 NaN                f     NaN
# 1                 9.0                f     NaN
# 2                 NaN                f     NaN
# 3                 NaN                f     NaN
# 4                 NaN                f     NaN
#
#                  jurisdiction_names instant_bookable cancellation_policy  \
# 0  DISTRICT OF COLUMBIA, WASHINGTON                f            flexible
# 1  DISTRICT OF COLUMBIA, WASHINGTON                f              strict
# 2                               NaN                f            flexible
# 3  DISTRICT OF COLUMBIA, WASHINGTON                f            flexible
# 4                               NaN                f            flexible
#
#    require_guest_profile_picture require_guest_phone_verification  \
# 0                              f                                f
# 1                              f                                f
# 2                              f                                f
# 3                              f                                f
# 4                              f                                f
#
#   calculated_host_listings_count reviews_per_month
# 0                             18               NaN
# 1                              1              2.11
# 2                              1              1.00
# 3                              1               NaN
# 4                              1               NaN
#
# [5 rows x 92 columns]

# %%
dc_listings['distance'] = np.abs(dc_listings.accommodates - our_acc_value)
dc_listings.distance.value_counts().sort_index()
# Out:
# 0      461
# 1     2294
# 2      503
# 3      279
# 4       35
# 5       73
# 6       17
# 7       22
# 8        7
# 9       12
# 10       2
# 11       4
# 12       6
# 13       8
# Name: distance, dtype: int64

# %%
dc_listings = dc_listings.sample(frac=1,random_state=0)
dc_listings = dc_listings.sort_values('distance')
dc_listings.price.head()
# Out:
# 2645     $75.00
# 2825    $120.00
# 2145     $90.00
# 2541     $50.00
# 3349    $105.00
# Name: price, dtype: object

# %%
dc_listings['price'] = dc_listings.price.str.replace("\$|,",'').astype(float)

mean_price = dc_listings.price.iloc[:5].mean()
mean_price
# Out:
# 88.0

# %%
dc_listings.drop('distance',axis=1)

train_df = dc_listings.copy().iloc[:2792]
test_df = dc_listings.copy().iloc[2792:]

# %%
def predict_price(new_listing_value,feature_column):
    temp_df = train_df
    temp_df['distance'] = np.abs(dc_listings[feature_column] - new_listing_value)
    temp_df = temp_df.sort_values('distance')
    knn_5 = temp_df.price.iloc[:5]
    predicted_price = knn_5.mean()
    return(predicted_price)

# %%
test_df['predicted_price'] = test_df.accommodates.apply(predict_price,feature_column='accommodates')

# %%
test_df.head()
# Out:
#            id                           listing_url       scrape_id  \
# 2850   451854   https://www.airbnb.com/rooms/451854  20151002231825
# 2279  6389926  https://www.airbnb.com/rooms/6389926  20151002231825
# 2771  2257488  https://www.airbnb.com/rooms/2257488  20151002231825
# 910   6037042  https://www.airbnb.com/rooms/6037042  20151002231825
# 2434  1578240  https://www.airbnb.com/rooms/1578240  20151002231825
#
#      last_scraped                               name  \
# 2850   2015-10-03              Living Room/1BR condo
# 2279   2015-10-03  Super comfy couch in Adams Morgan
# 2771   2015-10-03     Dream loft, quiet in the city
# 910    2015-10-03     2 bedroom/2 bath in Georgetown
# 2434   2015-10-03      Embassy Suite on Embassy Row!
#
#                                                 summary  \
# 2850                                                NaN
# 2279  For interstellar travelers looking for a place...
# 2771  Newly renovated!! Exposed brick walls and dram...
# 910   This 2 bedroom/2 bath suite is located within ...
# 2434  The new kid on the block! Just recently listed...
#
#                                                   space  \
# 2850  Large one bedroom condo in the nation's capito...
# 2279                                                NaN
# 2771  Newly renovated DC row house with amazing 12 f...
# 910   This spacious nonsmoking unt is perfect for th...
# 2434  Located on coveted, Embassy Row in the heart o...
#
#                                             description experiences_offered  \
# 2850  Large one bedroom condo in the nation's capito...                none
# 2279  For interstellar travelers looking for a place...                none
# 2771  Newly renovated!! Exposed brick walls and dram...                none
# 910   This 2 bedroom/2 bath suite is located within ...                none
# 2434  The new kid on the block! Just recently listed...                none
#
#                                   neighborhood_overview       ...        \
# 2850                                                NaN       ...
# 2279  Very quiet but extremely well located neighbor...       ...
# 2771  Everything is 2 blocks away, but you are on a ...       ...
# 910   Georgetown is a quaint historic neighborhood i...       ...
# 2434                                                NaN       ...
#
#      license                jurisdiction_names instant_bookable  \
# 2850     NaN  DISTRICT OF COLUMBIA, WASHINGTON                f
# 2279     NaN  DISTRICT OF COLUMBIA, WASHINGTON                f
# 2771     NaN  DISTRICT OF COLUMBIA, WASHINGTON                t
# 910      NaN  DISTRICT OF COLUMBIA, WASHINGTON                f
# 2434     NaN  DISTRICT OF COLUMBIA, WASHINGTON                f
#
#      cancellation_policy require_guest_profile_picture  \
# 2850            moderate                             t
# 2279            flexible                             f
# 2771              strict                             f
# 910             flexible                             f
# 2434              strict                             f
#
#      require_guest_phone_verification  calculated_host_listings_count  \
# 2850                                t                               1
# 2279                                f                               2
# 2771                                f                               6
# 910                                 f                              16
# 2434                                f                              27
#
#      reviews_per_month distance predicted_price
# 2850              2.53        2            83.6
# 2279              1.70        2            83.6
# 2771              1.53        2           340.4
# 910               1.00        2           340.4
# 2434              0.43        2           340.4
#
# [5 rows x 94 columns]

# %%
test_df['squared_error'] = (test_df['predicted_price'] - test_df['price'])**(2)
mse = test_df['squared_error'].mean()
rmse = mse ** (1/2)
rmse
# Out:
# 212.98927967051543

# %%
for feature in ['accommodates','bedrooms','bathrooms','number_of_reviews']:
    test_df['predicted_price'] = test_df.accommodates.apply(predict_price,feature_column=feature)
    
    test_df['squared_error'] = (test_df['predicted_price'] - test_df['price'])**(2)
    mse = test_df['squared_error'].mean()
    rmse = mse ** (1/2)
    print("RMSE for the {} column: {}".format(feature,rmse))
# Out:
# RMSE for the accommodates column: 212.98927967051543
# RMSE for the bedrooms column: 216.49048609414763
# RMSE for the bathrooms column: 216.89419042215684
# RMSE for the number_of_reviews column: 240.21528314334847
